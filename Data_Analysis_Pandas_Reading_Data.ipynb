# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pd.read_csv?

# %%
df1 = pd.read_csv('datasets_2761_4580_kospi_000020.csv')

# %%
df1.head()
# Out:
#          Date         Open         High          Low         Close  \
# 0  2000-01-04  2658.120117  3110.570068  2658.120117  15552.850586
# 1  2000-01-05  3167.120117  3572.439941  2940.899902  16495.451172
# 2  2000-01-06  3299.090088  3468.750000  2808.939941  14327.450195
# 3  2000-01-07  2978.600098  3289.659912  2827.790039  16448.298828
# 4  2000-01-10  3638.419922  3694.979980  3157.699951  16024.150391
#
#      Adj Close   Volume
# 0  2752.192383   898582
# 1  2918.992432  3865389
# 2  2535.348633  1382353
# 3  2910.648682  2402938
# 4  2835.592041  3993227

# %%
df = df1[['Date','Close']]

# %%
df.head()
# Out:
#          Date         Close
# 0  2000-01-04  15552.850586
# 1  2000-01-05  16495.451172
# 2  2000-01-06  14327.450195
# 3  2000-01-07  16448.298828
# 4  2000-01-10  16024.150391

# %%
df.columns = ['Timestamp', 'Price']

# %%
df.head()
# Out:
#     Timestamp         Price
# 0  2000-01-04  15552.850586
# 1  2000-01-05  16495.451172
# 2  2000-01-06  14327.450195
# 3  2000-01-07  16448.298828
# 4  2000-01-10  16024.150391

# %%
df.shape
# Out:
# (4322, 2)

# %%
df.tail(3)
# Out:
#        Timestamp   Price
# 4319  2017-07-05  8340.0
# 4320  2017-07-06  8400.0
# 4321  2017-07-07  8270.0

# %%
df.dtypes
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %%
pd.to_datetime(df['Timestamp']).head()
# Out:
# 0   2000-01-04
# 1   2000-01-05
# 2   2000-01-06
# 3   2000-01-07
# 4   2000-01-10
# Name: Timestamp, dtype: datetime64[ns]

# %%
df.head()
# Out:
#     Timestamp         Price
# 0  2000-01-04  15552.850586
# 1  2000-01-05  16495.451172
# 2  2000-01-06  14327.450195
# 3  2000-01-07  16448.298828
# 4  2000-01-10  16024.150391

# %%
df.dtypes
# Out:
# Timestamp     object
# Price        float64
# dtype: object

# %%
df.set_index('Timestamp', inplace=True)

# %%
df.head()
# Out:
#                    Price
# Timestamp
# 2000-01-04  15552.850586
# 2000-01-05  16495.451172
# 2000-01-06  14327.450195
# 2000-01-07  16448.298828
# 2000-01-10  16024.150391

# %%
df.loc['2000-02-01']
# Out:
# Price    13479.100586
# Name: 2000-02-01, dtype: float64

# %%
# Putting everything together
df = df1[['Date','Close']]
df.columns = ['Timestamp', 'Price']
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df.set_index('Timestamp', inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df.head()
# Out:
#                    Price
# Timestamp
# 2000-01-04  15552.850586
# 2000-01-05  16495.451172
# 2000-01-06  14327.450195
# 2000-01-07  16448.298828
# 2000-01-10  16024.150391

# %%
# df = pd.read_csv(
#     'data/btc-market-price.csv',
#     header=None,
#     names=['Timestamp', 'Price'],
#     index_col=0,
#     parse_dates=True
# )

# %% [markdown]
# # Plotting Basic

# %%
df.plot()

# %%
plt.plot(df.index, df['Price'])

# %%
x = np.arange(-10,11)

# %%
plt.plot(x,x**2)

# %%
plt.figure(figsize=(12, 6))
plt.plot(x, x ** 2)
plt.plot(x, -1 * (x ** 2))

plt.title('My Nice Plot')
# Out:
# Text(0.5, 1.0, 'My Nice Plot')

# %%
df.plot(figsize=(16, 9), title='Bitcoin Price 2017-2018')

# %%
df1 = pd.read_csv('datasets_2761_4580_kospi_000020.csv',parse_dates=True, index_col=0)

# %%
Prices = pd.DataFrame(index=df.index)

# %%
Prices.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [2000-01-04 00:00:00, 2000-01-05 00:00:00, 2000-01-06 00:00:00, 2000-01-07 00:00:00, 2000-01-10 00:00:00]

# %%
Prices[['High','Low']] = df1[['High','Low']]
# Prices['Low'] = df1['Low']

# %%
Prices.head()
# Out:
#                    High          Low
# Timestamp
# 2000-01-04  3110.570068  2658.120117
# 2000-01-05  3572.439941  2940.899902
# 2000-01-06  3468.750000  2808.939941
# 2000-01-07  3289.659912  2827.790039
# 2000-01-10  3694.979980  3157.699951

# %%
Prices['Open'] = df1['Open']

# %%
Prices.head()
# Out:
#                    High          Low         Open
# Timestamp
# 2000-01-04  3110.570068  2658.120117  2658.120117
# 2000-01-05  3572.439941  2940.899902  3167.120117
# 2000-01-06  3468.750000  2808.939941  3299.090088
# 2000-01-07  3289.659912  2827.790039  2978.600098
# 2000-01-10  3694.979980  3157.699951  3638.419922

# %%
Prices.plot(figsize=(14,6))

# %%
Prices.iloc[1:120].plot(figsize=(12, 6))
