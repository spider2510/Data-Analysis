# %%
import pandas as pd

# %%
csv_url = 'https://repl.it/@AkhilWase/fcc-demographic-data-analyzer#adult.data.csv'
df = pd.read_csv('adult.data.csv',delimiter=',')
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# salary            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# How many of each race are represented in this dataset? This should be a Pandas 
# series with race names as the index labels.

df['race'].count()
# Out:
# 32561

# %%
# What is the average age of men?

a = df['race'].value_counts()

# %%
a.tolist()
# Out:
# [27816, 3124, 1039, 311, 271]

# %%
# What is the average age of men?

a = df[df['sex']=='Male']

# %%
a['age'].mean()
"{0:0.1f}".format(a['age'].mean())
# Out:
# '39.4'

# %%
# What is the percentage of people who have a Bachelor's degree?

df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df['education'].value_counts('Bachelors')
# Out:
# HS-grad         0.322502
# Some-college    0.223918
# Bachelors       0.164461
# Masters         0.052916
# Assoc-voc       0.042443
# 11th            0.036086
# Assoc-acdm      0.032769
# 10th            0.028654
# 7th-8th         0.019840
# Prof-school     0.017690
# 9th             0.015786
# 12th            0.013298
# Doctorate       0.012684
# 5th-6th         0.010227
# 1st-4th         0.005160
# Preschool       0.001566
# Name: education, dtype: float64

# %%
a = df[df['education']=='Bachelors']
(len(a['education'])/len(df['education']))*100
# Out:
# 16.44605509658794

# %%
# What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
# What percentage of people without advanced education make more than 50K?
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# percentage with salary >50K
higher_education_rich = None
lower_education_rich = None
# `Bachelors`, `Masters`, or `Doctorate`

# %%
a = 100*len(df.loc[(df['salary']=='>50K')&((df['education']=='Bachelors')|(df['education']=='Masters')|(df['education']=='Doctorate'))])/len(df.loc[df['salary']=='>50K'])
a
# Out:
# 44.45861497258003

# %%
df['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
a = 100*len(df.loc[(df['salary']=='>50K')&((df['education']!='Bachelors')&(df['education']!='Masters')&(df['education']!='Doctorate')),'salary'])/len(df.loc[df['salary']=='>50K','salary'])
a
# Out:
# 55.54138502741997

# %%
df1 = df[df['salary'] == '>50K']
len(df1)
# Out:
# 7841

# %%
x = len(df[(df['education']=='Masters')&(df['salary']=='>50K')])
y= len(df[(df['education']=='Doctorate')&(df['salary']=='>50K')])
z = len(df[(df['education']=='Bachelors')&(df['salary']=='>50K')])

# %%
(x+y+z)/len(df['salary']=='>50K')
# Out:
# 0.10706059396210191

# %%
a = 100*len(df.loc[(df['salary']=='>50K')&((df['education']!='Bachelors')&(df['education']!='Masters')&(df['education']!='Doctorate')),'salary'])/len(df.loc[df['salary']=='>50K','salary'])
a
# Out:
# 55.54138502741997

# %%
df['Advanced']= ["Yes" if x in ['Bachelors','Masters','Doctorate'] else 'No' for x in df['education']]
df['Advanced'].count()
# Out:
# 32561

# %%
advanced_df = df[df['advanced']=='Yes']
advanced_df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 8   31           Private   45781    Masters             14
#
#        marital-status       occupation   relationship   race     sex  \
# 0       Never-married     Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White    Male
# 4  Married-civ-spouse   Prof-specialty           Wife  Black  Female
# 5  Married-civ-spouse  Exec-managerial           Wife  White  Female
# 8       Never-married   Prof-specialty  Not-in-family  White  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary advanced
# 0          2174             0              40  United-States  <=50K      Yes
# ...

# %%
advanced_percentage = pd.Index(advanced_df['salary']).value_counts(normalize=True)*100
advanced_percentage
# Out:
# <=50K    53.464157
# >50K     46.535843
# Name: salary, dtype: float64

# %%
advanced_percentage_greater50 = round(advanced_percentage.loc['>50K'],1)

# %%
advanced_percentage_greater50
# Out:
# 46.5

# %%
# df['Advanced'] = df.loc[(df['education']=='Bachelors')|(df['education']=='Masters')|(df['education']=='Doctorate')]

# %%
df['advanced']= ["true" if x in ['Bachelors','Masters','Doctorate'] else 'false' for x in df['education']]

# %%
ad_df = df[df['advanced']=='true']

# %%
ad = pd.Index(ad_df['salary']).value_counts(normalize=True)*100
ad
# Out:
# <=50K    53.464157
# >50K     46.535843
# Name: salary, dtype: float64

# %%
print(round(ad.loc['>50K'],1))
# Out:
# 46.5

# %%
nad_df = df[df['advanced']=='false']

# %%
nad = pd.Index(nad_df['salary']).value_counts(normalize=True)*100
nad = pd.Index(nad_df['salary']).value_counts(normalize=True)*100

# %%
# print(round(ad.loc['>50K'],1))

no_advanced_df = df[df['Advanced']=='No']

no_advanced_percentage = pd.Index(no_advanced_df['salary']).value_counts(normalize=True)*100
print(no_advanced_percentage)

no_advanced_percentage_greater50 = round(no_advanced_percentage.loc['>50K'],1)
# Out:
# <=50K    82.62864
# >50K     17.37136
# Name: salary, dtype: float64

# %%
no_advanced_percentage_greater50
# Out:
# 17.4

# %%
# What is the minimum number of hours a person works per week (hours-per-week feature)?

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 17 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# salary            32561 non-null object
# advanced          32561 non-null object
# Advanced          32561 non-null object
# dtypes: int64(6), object(11)
# memory usage: 4.2+ MB

# %%
df['hours-per-week'].min()
# Out:
# 1

# %%
# # What percentage of the people who work the minimum number of hours per week have a salary of >50K?

a = df[(df['hours-per-week'] == df['hours-per-week'].min())&(df['salary']=='>50K')]
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 189     58         State-gov  109567     Doctorate             16
# 1036    66      Self-emp-inc  150726           9th              5
# 1262    69                 ?  195779     Assoc-voc             11
# 5590    78                 ?  363134       HS-grad              9
# 5632    45                 ?  189564       Masters             14
# 5766    62                 ?   97231  Some-college             10
# 5808    76                 ?  211574          10th              6
# 8447    67                 ?  244122     Assoc-voc             11
# 9147    75                 ?  260543          10th              6
# 11451   27           Private  147951       HS-grad              9
# 19337   72                 ?   76860       HS-grad              9
# 19750   23           Private   72887       HS-grad              9
# 20072   65                 ?   76043       HS-grad              9
# ...

# %%
a = df[df['salary']=='>50K']
a
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 8       31           Private   45781       Masters             14
# 9       42           Private  159449     Bachelors             13
# 10      37           Private  280464  Some-college             10
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# 19      43  Self-emp-not-inc  292175       Masters             14
# 20      40           Private  193524     Doctorate             16
# 25      56         Local-gov  216851     Bachelors             13
# 27      54                 ?  180211  Some-college             10
# 38      31           Private   84154  Some-college             10
# 45      57       Federal-gov  337895     Bachelors             13
# 52      47           Private   51835   Prof-school             15
# ...

# %%
a
# Out:
#        age  workclass  fnlwgt  education  education-num      marital-status  \
# 189     58  State-gov  109567  Doctorate             16  Married-civ-spouse
# 20072   65          ?   76043    HS-grad              9  Married-civ-spouse
#
#            occupation relationship   race   sex  capital-gain  capital-loss  \
# 189    Prof-specialty      Husband  White  Male             0             0
# 20072               ?      Husband  White  Male             0             0
#
#        hours-per-week native-country salary advanced Advanced
# 189                 1  United-States   >50K     true      Yes
# 20072               1  United-States   >50K    false       No

# %%
a = len(df[(df['hours-per-week'] == df['hours-per-week'].min())&(df['salary']=='>50K')])/len(df[df['hours-per-week'] == df['hours-per-week'].min()])

# %%
round(a*100,1)
# Out:
# 10.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 17 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education-num     32561 non-null int64
# marital-status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital-gain      32561 non-null int64
# capital-loss      32561 non-null int64
# hours-per-week    32561 non-null int64
# native-country    32561 non-null object
# salary            32561 non-null object
# advanced          32561 non-null object
# Advanced          32561 non-null object
# dtypes: int64(6), object(11)
# memory usage: 4.2+ MB

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary advanced  \
# 0          2174             0              40  United-States  <=50K     true
# ...

# %%
a = df.loc[df['salary']== '>50K']
a['native-country'].value_counts()
# Out:
# United-States         7171
# ?                      146
# Philippines             61
# Germany                 44
# India                   40
# Canada                  39
# Mexico                  33
# England                 30
# Italy                   25
# Cuba                    25
# Japan                   24
# China                   20
# Taiwan                  20
# Iran                    18
# South                   16
# France                  12
# Poland                  12
# Puerto-Rico             12
# Jamaica                 10
# El-Salvador              9
# Greece                   8
# Cambodia                 7
# Hong                     6
# Yugoslavia               6
# Vietnam                  5
# Ireland                  5
# Portugal                 4
# Ecuador                  4
# Haiti                    4
# Scotland                 3
# Guatemala                3
# Thailand                 3
# Hungary                  3
# Laos                     2
# ...

# %%
# a = a['native-country'].value_counts(normalize=True)*100

# %%
country4 = country3[country3['salary']=='>50K'].sort_values(by=['percentage'], ascending = False)
highest_earning_country = (country4[0:1]['native-country']).values[0]
highest_earning_country_percentage = round((country4[0:1]['percentage']).values[0],1)

# %%
country2 = df.groupby('native-country')
country2.head()
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 0       39         State-gov   77516     Bachelors             13
# 1       50  Self-emp-not-inc   83311     Bachelors             13
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 4       28           Private  338409     Bachelors             13
# 5       37           Private  284582       Masters             14
# 6       49           Private  160187           9th              5
# 11      30         State-gov  141297     Bachelors             13
# 14      40           Private  121772     Assoc-voc             11
# 15      34           Private  245487       7th-8th              4
# 27      54                 ?  180211  Some-college             10
# 35      48           Private  242406          11th              7
# 38      31           Private   84154  Some-college             10
# ...

# %%
value_after_group = country2['salary'].value_counts(normalize=True)*100
value_after_group
# Out:
# native-country              salary
# ?                           <=50K      74.957118
#                             >50K       25.042882
# Cambodia                    <=50K      63.157895
#                             >50K       36.842105
# Canada                      <=50K      67.768595
#                             >50K       32.231405
# China                       <=50K      73.333333
#                             >50K       26.666667
# Columbia                    <=50K      96.610169
#                             >50K        3.389831
# Cuba                        <=50K      73.684211
#                             >50K       26.315789
# Dominican-Republic          <=50K      97.142857
#                             >50K        2.857143
# Ecuador                     <=50K      85.714286
#                             >50K       14.285714
# El-Salvador                 <=50K      91.509434
#                             >50K        8.490566
# ...

# %%
country3 = value_after_group.reset_index(name='percentage')
country3
# Out:
#                 native-country salary  percentage
# 0                            ?  <=50K   74.957118
# 1                            ?   >50K   25.042882
# 2                     Cambodia  <=50K   63.157895
# 3                     Cambodia   >50K   36.842105
# 4                       Canada  <=50K   67.768595
# 5                       Canada   >50K   32.231405
# 6                        China  <=50K   73.333333
# 7                        China   >50K   26.666667
# 8                     Columbia  <=50K   96.610169
# 9                     Columbia   >50K    3.389831
# 10                        Cuba  <=50K   73.684211
# 11                        Cuba   >50K   26.315789
# 12          Dominican-Republic  <=50K   97.142857
# 13          Dominican-Republic   >50K    2.857143
# 14                     Ecuador  <=50K   85.714286
# 15                     Ecuador   >50K   14.285714
# 16                 El-Salvador  <=50K   91.509434
# 17                 El-Salvador   >50K    8.490566
# ...

# %%
country4 = country3[country3['salary']=='>50K'].sort_values(by=['percentage'], ascending = False)
country4
# Out:
#         native-country salary  percentage
# 40                Iran   >50K   41.860465
# 21              France   >50K   41.379310
# 38               India   >50K   40.000000
# 71              Taiwan   >50K   39.215686
# 48               Japan   >50K   38.709677
# 81          Yugoslavia   >50K   37.500000
# 3             Cambodia   >50K   36.842105
# 44               Italy   >50K   34.246575
# 19             England   >50K   33.333333
# 5               Canada   >50K   32.231405
# 23             Germany   >50K   32.116788
# 59         Philippines   >50K   30.808081
# 34                Hong   >50K   30.000000
# 25              Greece   >50K   27.586207
# 7                China   >50K   26.666667
# 11                Cuba   >50K   26.315789
# 1                    ?   >50K   25.042882
# 67            Scotland   >50K   25.000000
# 77       United-States   >50K   24.583476
# 36             Hungary   >50K   23.076923
# 42             Ireland   >50K   20.833333
# ...

# %%
a = df.loc[(df['salary']=='>50K')&(df['native-country']=='India'),'occupation'].value_counts()

# %%
a
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Tech-support         2
# Other-service        2
# Transport-moving     1
# Sales                1
# Adm-clerical         1
# Name: occupation, dtype: int64

# %%
a.index[0]
# Out:
# 'Prof-specialty'

# %%
# https://repl.it/join/jklmkwzi-akhilwase
